# %%
import json
import os

in_folder = "D:/Projects/Database/Zillow_coco/annotations_big"

in_path = os.path.join(in_folder , "instances_train2017_10.json")
f = open(in_path)

anno = json.load(f)
print(anno['annotations'])
# Out:
# [{'image_id': 0, 'file_name': '0919/panos/floor_01_partial_room_02_pano_35.jpg', 'id': 0, 'iscrowd': 0, 'category_id': 1, 'area': 550903.9189922363, 'bbox': [459.7200012207031, 280.6400146484375, 1013.6600036621094, 543.47998046875], 'irr_box': [0.4719482436776161, 0.5394335985183716, 0.24747558683156967, 0.26537108421325684, 0.24747558683156967, 0.3222949206829071, 0.24747558683156967, 0.26537108421325684, 0.24747558683156967, 0.20930665731430054]}, {'image_id': 1, 'file_name': '0919/panos/floor_01_partial_room_03_pano_25.jpg', 'id': 1, 'iscrowd': 0, 'category_id': 1, 'area': 536994.4080505371, 'bbox': [467.2300109863281, 228.94000244140625, 713.1399841308594, 753.0], 'irr_box': [0.4022460952401161, 0.5912500023841858, 0.1741064414381981, 0.36767578125, 0.1741064414381981, 0.48287109285593033, 0.1741064414381981, 0.36767578125, 0.1741064414381981, 0.3145703077316284]}, {'image_id': 2, 'file_name': '0919/panos/floor_01_partial_room_07_pano_40.jpg', 'id': 2, 'iscrowd': 0, 'category_id
# ...
